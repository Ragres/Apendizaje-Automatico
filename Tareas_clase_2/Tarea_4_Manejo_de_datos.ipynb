# %%
import pandas as pd

# %%
Datos=pd.read_csv("LifeExpectancy.csv")

# %%
#Se eliminara la columna Hepatitis B
Datos_mod=Datos.drop(columns="Hepatitis B")

# %%
Datos_mod
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0              263
# 1     Afghanistan  2014  Developing             59.9              271
# 2     Afghanistan  2013  Developing             59.9              268
# 3     Afghanistan  2012  Developing             59.5              272
# 4     Afghanistan  2011  Developing             59.2              275
# ...           ...   ...         ...              ...              ...
# 2923     Zimbabwe  2004  Developing             44.3              723
# 2924     Zimbabwe  2003  Developing             44.5              715
# 2925     Zimbabwe  2002  Developing             44.8               73
# 2926     Zimbabwe  2001  Developing             45.3              686
# 2927     Zimbabwe  2000  Developing             46.0              665
#
#       infant deaths  Alcohol  percentage expenditure  Measles    BMI   ...  \
# ...

# %%
#Para filtarado se usaran solo los datos de 2015
Datos_2015=Datos[Datos["Year"]==2015]

# %%
Datos_2015.head()
# Out:
#                 Country  Year      Status  Life expectancy  Adult Mortality  \
# 0           Afghanistan  2015  Developing             65.0              263
# 16              Albania  2015  Developing             77.8               74
# 32              Algeria  2015  Developing             75.6               19
# 48               Angola  2015  Developing             52.4              335
# 64  Antigua and Barbuda  2015  Developing             76.4               13
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0              62     0.01               71.279624         65.0      1154
# 16              0     4.60              364.975229         99.0         0
# 32             21      NaN                0.000000         95.0        63
# 48             66      NaN                0.000000         64.0       118
# 64              0      NaN                0.000000         99.0         0
#
# ...

# %%
#Crearemos dos subconjuntos uno para los paises en desarrollo y uno para los paises en vias de desarrollo

Paises_desarrollados=Datos[Datos["Status"]=="Developed"]
Paises_vias_desarrollo=Datos[Datos["Status"]=="Developing"]

# %%
Paises_desarrollados.head()
# Out:
#        Country  Year     Status  Life expectancy  Adult Mortality  \
# 112  Australia  2015  Developed             82.8               59
# 113  Australia  2014  Developed             82.7                6
# 114  Australia  2013  Developed             82.5               61
# 115  Australia  2012  Developed             82.3               61
# 116  Australia  2011  Developed             82.0               63
#
#      infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 112              1      NaN                 0.00000         93.0        74
# 113              1     9.71             10769.36305         91.0       340
# 114              1     9.87             11734.85381         91.0       158
# 115              1    10.03             11714.99858         91.0       199
# 116              1    10.30             10986.26527         92.0       190
#
#      ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# ...

# %%
Paises_vias_desarrollo.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0              263
# 1  Afghanistan  2014  Developing             59.9              271
# 2  Afghanistan  2013  Developing             59.9              268
# 3  Afghanistan  2012  Developing             59.5              272
# 4  Afghanistan  2011  Developing             59.2              275
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...
